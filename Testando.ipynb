# %% [markdown]
# # Testando Para Sucro Studio
# ### Jupyter Notebook

# %% [markdown]
# ![PTR_Analytics.png](attachment:PTR_Analytics.png)

# %%
print ("Hello Word!")

# %%
print ("PTR Analytics")

# %% [markdown]
# ![Caldeiraria.jpg](attachment:Caldeiraria.jpg)

# %%
import pandas as pd
import numpy as np

# %%
dados = [[1,2,3],
         [4,5,6],
         [7,8,9]
        ]
colunas = ['Gui','Léo','Mel']
index = ['G','L','M']
df = pd.DataFrame (data=dados, columns=colunas, index=index, dtype='float64')

# %%
df
# Out:
#    Gui  Léo  Mel
# G  1.0  2.0  3.0
# L  4.0  5.0  6.0
# M  7.0  8.0  9.0

# %%
dados = np.random.randint(low=0, high=10, size=(5, 5))
dados
# Out:
# array([[0, 0, 1, 0, 7],
#        [8, 5, 3, 5, 3],
#        [6, 0, 0, 4, 7],
#        [9, 7, 1, 0, 0],
#        [7, 7, 9, 5, 6]])

# %%
colunas = ['A','B','C','D','E']

# %%
df = pd.DataFrame(data=dados, columns=colunas)
df
# Out:
#    A  B  C  D  E
# 0  0  0  1  0  7
# 1  8  5  3  5  3
# 2  6  0  0  4  7
# 3  9  7  1  0  0
# 4  7  7  9  5  6

# %%
import pandas as pd

# %%
df = pd.read_excel("USA P.T.R.xlsx", sheet_name="Plan1")

# %%
df.head()
# Out:
#    Nº PTR  Data    Mês   Ano      Hora           Local  \
# 0    9021    28  Junho  2019  00h30min        Extração
# 1    9022    28  Junho  2019  01h30min        Extração
# 2    9023    29  Junho  2019  02h45min     Fermentação
# 3    9047    29  Junho  2019  09h00min  Parque Químico
# 4    9046    29  Junho  2019  11h30min      Utilidades
#
#        Escopo do Trabalho                      Permissões        Permissões.1  \
# 0  Planetário do 5º terno              Içamento de Cargas  Trabalho em Altura
# 1  Planetário do 5º terno               Trabalho a Quente  Trabalho em Altura
# 2            Acesso no TQ              Trabalho em Altura    Espaço Confinado
# 3   Retirada de vazamento  Trabalho com Produtos Químicos   Trabalho a Quente
# 4                Manobras              Trabalho em Altura                 NaN
#
#   Permissões.2 Setor Executante     Autorização
# 0          NaN         Extração  João dos Anjos
# 1          NaN         Extração     João Molina
# ...

# %%
df = pd.read_excel("USA P.T.R.xlsx", sheet_name="Plan2")

# %%
df.head()
# Out:
#        1    Janeiro    2019  00h00min                Extração  Unnamed: 5  \
# NaN  2.0  Fevereiro  2020.0  00h15min              Utilidades         NaN
# NaN  3.0      Março  2021.0  00h30min     Tratamento de Caldo         NaN
# NaN  4.0      Abril  2022.0  00h45min             Fermentação         NaN
# NaN  5.0       Maio  2023.0  01h00min              Destilação         NaN
# NaN  6.0      Junho  2024.0  01h15min  Carregamento de Etanol         NaN
#
#                         Trabalho a Quente  \
# NaN                    Trabalho em Altura
# NaN                      Espaço Confinado
# NaN  Escavações, Perfurações e Demolições
# NaN                    Içamento de Cargas
# NaN        Trabalho com Produtos Químicos
#
#                       Trabalho a Quente.1  \
# NaN                    Trabalho em Altura
# NaN                      Espaço Confinado
# NaN  Escavações, Perfurações e Demolições
# NaN                    Içamento de Cargas
# NaN        Trabalho com Produtos Químicos
#
# ...
